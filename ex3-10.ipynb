# %%
from scipy.stats import norm
mean = 64.43
std_dev = 2.99
x = norm.cdf(69.348112344584905031297239474952220916748046875,mean,std_dev)
print(f"{x:.50f}")
# Out:
# 0.94999999999999984456877655247808434069156646728516

# %%
x=norm.ppf(0.95,mean,std_dev)
print(f"{x:.45f}")
# Out:
# 69.348112344584905031297239474952220916748046875

# %%
import random
for i in range(0,1000):
    random_p = random.uniform(0.0,1.0)
    random_weight = norm.ppf(random_p,loc=64.43,scale=2.99)
    print(random_weight)

# %%
mean = 18
std_dev = 1.5
x = norm.cdf(21,mean,std_dev)-norm.cdf(15,mean,std_dev)
print(x)
# Out:
# 0.9544997361036416

# %%
v= [3,2]
print(v)
# Out:
# [3, 2]

# %%
import numpy as np

# %%
v= np.array([2,3])
print(v)
# Out:
# [2 3]

# %%
from numpy import array
v = array([3,2])
w = array([2,-1])
v_plus_w = v + w
print(v_plus_w)
# Out:
# [5 1]

# %%
v = np.array([3,1])
scaled_v = 2 * v
print(scaled_v)
# Out:
# [6 2]
