# %% [markdown]
# $$
# \begin{bmatrix}
# 1 & 2 & 3
# \\
# 4 & 5 & 6
# \end{bmatrix}^T
# =
# \begin{bmatrix}
# 1 & 4
# \\
# 2 & 5
# \\
# 3 & 6
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# \begin{bmatrix}
# 1 & 2 & 3
# \\
# 4 & 5 & 6
# \\
# 7 & 8 & 9
# \end{bmatrix}^T
# =
# \begin{bmatrix}
# 1 & 4 & 7
# \\
# 2 & 5 & 8
# \\
# 3 & 6 & 9
# \end{bmatrix}
# $$
